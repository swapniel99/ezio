# %%
# !nvidia-smi
# Out:
# Sat Oct 24 16:05:23 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/theschoolofai/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 156, done.
# remote: Total 156 (delta 0), reused 0 (delta 0), pack-reused 156
# Receiving objects: 100% (156/156), 12.74 MiB | 42.37 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd YoloV3/
# Out:
# /content/YoloV3

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import shutil
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
os.mkdir('weights')

# %%
shutil.copy('/content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/yolov3-spp-ultralytics.pt','/content/YoloV3/weights/')
# Out:
# '/content/YoloV3/weights/yolov3-spp-ultralytics.pt'

# %%
shutil.copy('/content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/ppe.zip','/content/YoloV3/data/')
# Out:
# '/content/YoloV3/data/ppe.zip'

# %%
shutil.copy('/content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/yolov3-ppe.cfg','/content/YoloV3/cfg/')
# Out:
# '/content/YoloV3/cfg/yolov3-ppe.cfg'

# %%
# !unzip '/content/YoloV3/data/ppe.zip' -d '/content/YoloV3/data/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/YoloV3/data/__MACOSX/ppe/labels/._close-up-portrait-of-young-black-woman-wearing-face-medical-mask-to-picture-id1250529689.txt
#   inflating: /content/YoloV3/data/ppe/labels/images (68).txt
#   inflating: /content/YoloV3/data/__MACOSX/ppe/labels/._images (68).txt
#   inflating: /content/YoloV3/data/ppe/labels/Jimg059.txt
#   inflating: /content/YoloV3/data/__MACOSX/ppe/labels/._Jimg059.txt
#   inflating: /content/YoloV3/data/ppe/labels/N63.txt
#   inflating: /content/YoloV3/data/__MACOSX/ppe/labels/._N63.txt
#   inflating: /content/YoloV3/data/ppe/labels/ss_6.txt
#   inflating: /content/YoloV3/data/__MACOSX/ppe/labels/._ss_6.txt
#   inflating: /content/YoloV3/data/ppe/labels/majdoor_18.txt
#   inflating: /content/YoloV3/data/__MACOSX/ppe/labels/._majdoor_18.txt
#   inflating: /content/YoloV3/data/ppe/labels/N77.txt
#   inflating: /content/YoloV3/data/__MACOSX/ppe/labels/._N77.txt
# ...

# %%
# !python train.py --data data/ppe/ppe.data --batch 10 --cache --cfg cfg/yolov3-ppe.cfg --epochs 100
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-ppe.cfg', data='data/ppe/ppe.data', device='', epochs=100, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-24 16:06:49.352722: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2785 found, 209 missing, 38 empty, 0 duplicate, for 3032 images): 100% 3032/3032 [00:00<00:00, 8274.43it/s]
# Caching images (1.7GB): 100% 3032/3032 [00:20<00:00, 148.98it/s]
# ...

# %%
# !cp -R 'weights/' '/content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/'

# %%
# !python detect.py --conf-thres 0.1 --output '/content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/output' --names data/ppe/ppe.names --source '/content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/input_video_3.mp4' --cfg cfg/yolov3-ppe.cfg --weights weights/best.pt
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (9588/14584) /content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/input_video_3.mp4: 320x512 Done. (0.018s)
# video 1/1 (9589/14584) /content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/input_video_3.mp4: 320x512 Done. (0.019s)
# video 1/1 (9590/14584) /content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/input_video_3.mp4: 320x512 Done. (0.019s)
# video 1/1 (9591/14584) /content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/input_video_3.mp4: 320x512 Done. (0.018s)
# video 1/1 (9592/14584) /content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/input_video_3.mp4: 320x512 1 hardhats, Done. (0.019s)
# video 1/1 (9593/14584) /content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/input_video_3.mp4: 320x512 1 hardhats, Done. (0.018s)
# video 1/1 (9594/14584) /content/gdrive/My Drive/EVA5/Session_13/YOLOV3_custom/input_video_3.mp4: 320x512 1 hardhats, 1 masks, Done. (0.018s)
# ...
